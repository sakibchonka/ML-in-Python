# %%
import pandas as pd

# %%
df = pd.read_csv("datasets//food-consumption.csv")
df.head()
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %%
df1 = df.iloc[:,df.columns!='Country']
df1.head()
# Out:
#    Real coffee  Instant coffee  Tea  Sweetener  Biscuits  Powder soup  \
# 0           90              49   88       19.0      57.0           51
# 1           82              10   60        2.0      55.0           41
# 2           88              42   63        4.0      76.0           53
# 3           96              62   98       32.0      62.0           67
# 4           94              38   48       11.0      74.0           37
#
#    Tin soup  Potatoes  Frozen fish  Frozen veggies  Apples  Oranges  \
# 0        19        21           27              21      81       75
# 1         3         2            4               2      67       71
# 2        11        23           11               5      87       84
# 3        43         7           14              14      83       89
# 4        23         9           13              12      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# ...

# %%
from sklearn.impute import SimpleImputer

my_imputer = SimpleImputer()
imputed_df = pd.DataFrame(my_imputer.fit_transform(df1))
imputed_df.columns = df1.columns

imputed_df.isna().sum()
# Out:
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %%
df = pd.read_csv("datasets//ordinal-data.csv")
df.head()
# Out:
#   Breakfast  Number
# 0  Everyday       1
# 1     Never       2
# 2     Never       3
# 3  Everyday       4
# 4    Rarely       5

# %%
s = df.dtypes == 'object'
object_cols = list(s[s].index)
object_cols
# Out:
# ['Breakfast']

# %%
from sklearn.preprocessing import OrdinalEncoder

label_df = df.copy()
ordinal_encoder = OrdinalEncoder()
label_df[object_cols] = ordinal_encoder.fit_transform(df[object_cols])

label_df
# Out:
#    Breakfast  Number
# 0        0.0       1
# 1        2.0       2
# 2        2.0       3
# 3        0.0       4
# 4        3.0       5
# 5        2.0       6
# 6        1.0       7
# 7        3.0       8
